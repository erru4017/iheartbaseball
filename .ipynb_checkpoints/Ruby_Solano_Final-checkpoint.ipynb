# %% [markdown]
# Erin Ruby and Courtney Solano

# %% [markdown]
# # Final#
# #### CSCI 4831 - Sabermetrics ####
# #### Instructor: Hoenigman ####
# #### Due: Wednesday, May 1 by 3pm ####

# %%
from pybaseball import statcast
from pybaseball import playerid_reverse_lookup
from pybaseball.lahman import *
from pybaseball.retrosheet import *
import pandas as pd
import numpy as np
import math
download_lahman() 
pd.set_option('display.max_columns', 5000)

# %%
import matplotlib.pyplot as plt
import scipy.stats as stats
# %matplotlib inline

# %%
df2016 = pd.read_csv("../data/2016/data2016.csv")

# %%
april2017 = pd.read_csv("../data/2017/dataApril2017.csv")
may2017 = pd.read_csv("../data/2017/dataMay2017.csv")
june2017 = pd.read_csv("../data/2017/dataJune2017.csv")
july2017 = pd.read_csv("../data/2017/dataJuly2017.csv")
aug2017 = pd.read_csv("../data/2017/dataAug2017.csv")
sep2017 = pd.read_csv("../data/2017/dataSept2017.csv")
oct2017 = pd.read_csv("../data/2017/dataOct2017.csv")
df2017 = pd.concat([april2017,may2017,june2017,july2017,aug2017,sep2017,oct2017])
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
april2018 = pd.read_csv("../data/2018/dataApril2018.csv")
may2018 = pd.read_csv("../data/2018/dataMay2018.csv")
june2018 = pd.read_csv("../data/2018/dataJune2018.csv")
july2018 = pd.read_csv("../data/2018/dataJuly2018.csv")
aug2018 = pd.read_csv("../data/2018/dataAug2018.csv")
sep2018 = pd.read_csv("../data/2018/dataSept2018.csv")
oct2018 = pd.read_csv("../data/2018/dataOct2018.csv")
df2018 = pd.concat([april2018,may2018,june2018,july2018,aug2018,sep2018,oct2018])
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df1618 = pd.concat([df2016, df2017, df2018])

# %% [markdown]
# # Comments from Rhonda #
# I wonder if you could consider whether the previous play increased win expectancy as a way to weight the WE on the next play. You would use (WE_Current/WE_previous) to give you a value around 1. Greater than 1 means they improved and <1 means they decreased. Use that to weight the next WE calculation. I have no idea what that would do, but it could be interesting. It might be noisy and you might want to consider WE over the previous 2 plays instead of 1, or previous 3 plays.

# %% [markdown]
# # Explanation of statistic #
# Win Expectancy is the percent chance that a team will win, given a current state in the game. The current win expectancy is calculated using historical data, looking at the percent of teams that have won, given a current state. The states consist of the inning number, whether is it is the top or bottom of the inning, if the team is tied or winning or losing by 1 point, how many outs there are, and runners on base.

# %% [markdown]
# # Demonstration #
# Your demonstration needs to be in the form of an application showing how the statistic
# works. You will need to have all of the necessary data in your application, and a visual presentation
# that is clear to the users. An example of a demonstration is a website where users can select players
# and see how the stat is calculated for those players. You might also do a mobile app. If you took
# 3308 or the mobile app class in ATLAS, this project will be a great application of the content
# covered in those classes. You can also produce a Jupyter notebook. I’ll give up to 5pts extra credit
# for anyone who produces an application more advanced than a Jupyter notebook.

# %% [markdown]
# # Evaluation of statistic #
# As part of your demonstration, you should include an evaluation of how your statistic
# compares to other statistics. This could be in the form of presenting other statistics along with
# your own. You may want to include a correlation score between your stat and other related stats.

# %% [markdown]
# # Presentation #
# For the presentation, please produce a 5-7 minute video that describes your project. You
# could do a screencast showing how your application works. If you do a website, you should also
# include the web address.

# %%
gameData = df1618.copy().groupby(['game_date', 'away_team', 'home_team']).max()[['away_score', 'home_score']]
gameData['W'] = gameData['home_score']>gameData['away_score']
gameData.head()
# Out:
#                                 away_score  home_score      W
# game_date  away_team home_team
# 2016-04-03 NYM       KC                3.0         4.0   True
#            STL       PIT               1.0         4.0   True
#            TOR       TB                5.0         3.0  False
# 2016-04-04 CHC       LAA               9.0         0.0  False
#            COL       ARI              10.0         5.0  False

# %%
totalGames = len(gameData['W'])
totalGames
# Out:
# 7135

# %%
states = df1618.copy()
df1618.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  at_bat_number  away_score away_team     ax  \
# 0           0           0.0           76.0         6.0       WSH -0.115
# 1           1           1.0           76.0         6.0       WSH  2.757
# 2           2           2.0           76.0         6.0       WSH -4.139
# 3           3           3.0           75.0         6.0       WSH  3.908
# 4           4           4.0           75.0         6.0       WSH -8.414
#
#        ay      az  babip_value  balls  bat_score    batter      bb_type  \
# 0  26.411 -27.599          0.0    0.0        1.0  571757.0          NaN
# 1  22.657 -27.545          NaN    0.0        1.0  571757.0          NaN
# 2  28.467 -18.474          NaN    0.0        1.0  571757.0          NaN
# 3  20.877 -31.352          1.0    0.0        1.0  649557.0  ground_ball
# 4  29.487 -17.462          NaN    0.0        1.0  649557.0          NaN
#
#    break_angle_deprecated  break_length_deprecated  \
# 0                     NaN                      NaN
# 1                     NaN                      NaN
# 2                     NaN                      NaN
# 3                     NaN                      NaN
# 4                     NaN                      NaN
#
#                                                  des           description  \
# 0          Jeremy Hazelbaker strikes out swinging.         swinging_strike
# 1                                                NaN                  foul
# 2                                                NaN         called_strike
# 3  Aledmys Diaz singles on a sharp ground ball to...  hit_into_play_no_out
# 4                                                NaN                  foul
#
#    effective_speed error  estimated_ba_using_speedangle  \
# 0           83.632   NaN                            NaN
# 1           83.710   NaN                            NaN
# 2           92.269   NaN                            NaN
# 3           81.884   NaN                          0.643
# 4           93.150   NaN                            NaN
#
#    estimated_woba_using_speedangle     events  fielder_2  fielder_2.1  \
# 0                              NaN  strikeout   446653.0     446653.0
# 1                              NaN        NaN   446653.0     446653.0
# 2                              NaN        NaN   446653.0     446653.0
# 3                            0.611     single   446653.0     446653.0
# 4                              NaN        NaN   446653.0     446653.0
#
#    fielder_3  fielder_4  fielder_5  fielder_6  fielder_7  fielder_8  \
# 0   475582.0   502517.0   543685.0   457787.0   150029.0   572191.0
# 1   475582.0   502517.0   543685.0   457787.0   150029.0   572191.0
# 2   475582.0   502517.0   543685.0   457787.0   150029.0   572191.0
# 3   475582.0   502517.0   543685.0   457787.0   150029.0   572191.0
# 4   475582.0   502517.0   543685.0   457787.0   150029.0   572191.0
#
#    fielder_9  fld_score   game_date   game_pk game_type  game_year   hc_x  \
# 0   547180.0        6.0  2016-04-30  447228.0         R     2016.0    NaN
# 1   547180.0        6.0  2016-04-30  447228.0         R     2016.0    NaN
# 2   547180.0        6.0  2016-04-30  447228.0         R     2016.0    NaN
# 3   547180.0        6.0  2016-04-30  447228.0         R     2016.0  63.96
# 4   547180.0        6.0  2016-04-30  447228.0         R     2016.0    NaN
#
#     hc_y  hit_distance_sc  hit_location  home_score home_team  \
# 0    NaN              NaN           2.0         1.0       STL
# 1    NaN            119.0           NaN         1.0       STL
# 2    NaN              NaN           NaN         1.0       STL
# 3  99.19            139.0           7.0         1.0       STL
# 4    NaN              NaN           NaN         1.0       STL
#
#   if_fielding_alignment  index  inning inning_topbot  iso_value  launch_angle  \
# 0              Standard    347     9.0           Bot        0.0           NaN
# 1              Standard    356     9.0           Bot        NaN          17.0
# 2              Standard    374     9.0           Bot        NaN           NaN
# 3              Standard    376     9.0           Bot        0.0           6.0
# 4              Standard    391     9.0           Bot        NaN           NaN
#
#    launch_speed  launch_speed_angle of_fielding_alignment     on_1b     on_2b  \
# 0           NaN                 NaN              Standard       NaN  649557.0
# 1          64.5                 NaN              Standard       NaN  649557.0
# 2           NaN                 NaN              Standard  649557.0       NaN
# 3         100.4                 4.0              Standard       NaN       NaN
# 4           NaN                 NaN              Standard       NaN       NaN
#
#    on_3b  outs_when_up p_throws     pfx_x     pfx_z       pitch_name  \
# 0    NaN           2.0        R -0.141133  0.621400           Slider
# 1    NaN           2.0        R  0.119108  0.624267           Slider
# 2    NaN           2.0        R -0.444517  1.266400  4-Seam Fastball
# 3    NaN           2.0        R  0.238792  0.273100           Slider
# 4    NaN           2.0        R -0.750683  1.313700  4-Seam Fastball
#
#    pitch_number pitch_type   pitcher  pitcher.1  plate_x  plate_z  \
# 0           3.0         SL  518875.0   518875.0    1.219    1.509
# 1           2.0         SL  518875.0   518875.0    0.831    2.266
# 2           1.0         FF  518875.0   518875.0   -0.430    2.919
# 3           5.0         SL  518875.0   518875.0    0.483    2.202
# 4           4.0         FF  518875.0   518875.0   -0.571    3.411
#
#     player_name  post_away_score  post_bat_score  post_fld_score  \
# 0  Shawn Kelley              6.0             1.0             6.0
# 1  Shawn Kelley              6.0             1.0             6.0
# 2  Shawn Kelley              6.0             1.0             6.0
# 3  Shawn Kelley              6.0             1.0             6.0
# 4  Shawn Kelley              6.0             1.0             6.0
#
#    post_home_score  release_extension  release_pos_x  release_pos_y  \
# 0              1.0              5.973        -1.0248        54.5290
# 1              1.0              5.964        -1.1890        54.5381
# 2              1.0              6.439        -1.1819        54.0632
# 3              1.0              5.927        -1.1029        54.5752
# 4              1.0              6.195        -1.1184        54.3071
#
#    release_pos_z  release_speed  release_spin_rate  spin_dir  \
# 0         5.4049           84.9             2327.0       NaN
# 1         5.6201           84.4                NaN       NaN
# 2         5.6702           92.3             1943.0       NaN
# 3         5.5981           82.4                NaN       NaN
# 4         5.6912           93.7             2093.0       NaN
#
#    spin_rate_deprecated stand  strikes          sv_id  sz_bot  sz_top  \
# 0                   NaN     L      2.0  160430_161819    1.57    3.48
# 1                   NaN     L      1.0  160430_161750    1.57    3.48
# 2                   NaN     L      0.0  160430_161714    1.57    3.58
# 3                   NaN     R      2.0  160430_161623    1.64    3.58
# 4                   NaN     R      2.0  160430_161556    1.64    3.58
#
#    tfs_deprecated  tfs_zulu_deprecated type  umpire    vx0      vy0    vz0  \
# 0             NaN                  NaN    S     NaN  5.356 -123.440 -3.395
# 1             NaN                  NaN    S     NaN  4.246 -122.791 -1.915
# 2             NaN                  NaN    S     NaN  2.894 -134.371 -2.851
# 3             NaN                  NaN    X     NaN  2.997 -119.989 -1.247
# 4             NaN                  NaN    S     NaN  3.306 -136.322 -2.118
#
#    woba_denom  woba_value  zone
# 0         1.0         0.0  14.0
# 1         NaN         NaN  14.0
# 2         NaN         NaN   4.0
# 3         1.0         0.9   9.0
# 4         NaN         NaN   1.0

# %%
inning = 9.0
inning_topbot = 'Bot' #home team

on_1b = 1
on_2b = 1
on_3b = 0
outs_when_up = 1

df_criteria = states.loc[(states['inning']==inning) & (states['inning_topbot']==inning_topbot)
                         &  (states['on_1b'].notnull()) & ((states['home_score'])-(states['away_score'])==-1)
                        & (states['on_2b'].notnull()) & (states['on_3b'].isnull()) 
                         & (states['outs_when_up']==outs_when_up)]
len(df_criteria)

df_criteria = df_criteria.groupby(['game_date', 'away_team', 'home_team']).max()[['away_score', 'home_score']]

t = len(df_criteria['home_score']>df_criteria['away_score'])
# df_criteria.head()

t/totalGames
# Out:
# 0.008269096005606167
